# %% [markdown]
# <a href="https://colab.research.google.com/github/juhi3101/ml_libraries/blob/main/Bokeh_assingment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# How can you create a Bokeh plot using Python code
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p = figure(title="Simple Scatter Plot", x_axis_label="X-axis", y_axis_label="Y-axis")
p.circle(x, y, size=10, color="navy", alpha=0.5)
output_notebook()
show(p)
# Out:
#   <div id="ea24350f-3d9c-476e-aadf-ca4ca5c48eed" data-root-id="p1001" style="display: contents;"></div>

# %%
#What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
'''
In Bokeh, glyphs are visual representations of data points that you can add to a plot to create various types of visualizations.
Glyphs can be used to create points, lines, bars, patches, and other graphical elements that convey information from your data.
Each type of glyph has its own properties that you can customize to control the appearance of the plot.'''

# %%
# How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
from bokeh.plotting import figure ,output_file, show

x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file("line.html")

p.xaxis.axis_label = "x_axis"
p.yaxis.axis_label = "y_axis"
p=figure(title = "line plot")
p.line(x,y)
show(p)
# Out:
#   <div id="f1044ba0-eddf-4262-8c79-cb1e270db161" data-root-id="p1367" style="display: contents;"></div>

# %%
# What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?

'''
A Bokeh server is a component of the Bokeh library that allows you to create interactive web applications with real-time updates.
With Bokeh server, you can build dynamic and interactive plots that can respond to user interactions, such as clicking, dragging, or input changes,
and update their content in real time.

Bokeh server enables you to create complex applications that involve not only static visualizations but also dynamic behaviors.
This is achieved by running a Python script on a Bokeh server, which serves as the backend for your interactive application.
'''
