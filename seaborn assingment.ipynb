# %%
# Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
'''
scatter plot Use: Scatter plots are used to visualize the relationship between two numerical variables.
Each data point is represented as a point on the plot, and patterns or trends can be easily observed.

displot Use: displot is primarily used to visualize the distribution of a single numerical variable.
It's a flexible function that can create different types of distribution plots, such as histograms, 
kernel density plots, and cumulative distribution plots.

relplot Use: relplot is used to create various types of plots that show the relationship between two numerical variables.
It's particularly helpful when you want to explore correlations, trends, and patterns between variables.

catplot Use: catplot is used to create various types of categorical plots, which are useful for understanding the distribution
and relationships of categorical and numerical variables.

jointplot is particularly useful when you want to explore the correlation and distribution between two numerical variables 
simultaneously. It offers insights into how the variables interact and allows you to quickly identify patterns and trends
within your data.
'''

# %%
# Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
#"timepoint" and y = "signal" for different events and regions.
#Note: timepoint, signal, event, and region are columns in the fmri dataset.

import seaborn as sns
fmri = sns.load_dataset("fmri")
fmri

sns.lineplot(x=fmri.timepoint , y = fmri.signal)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
# Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.

import seaborn as sns
import matplotlib.pyplot as plt

titanic_data = sns.load_dataset("titanic")

plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)  
sns.boxplot(data=titanic_data, x='pclass', y='age')
plt.title('Box Plot of Age by Pclass')

plt.subplot(1, 2, 2)  
sns.boxplot(data=titanic_data, x='pclass', y='fare')
plt.title('Box Plot of Fare by Pclass')

plt.tight_layout()

plt.show()

# %%
# Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue 
#parameter for the 'cut' column of the diamonds dataset.
 
    
import seaborn as sns
import matplotlib.pyplot as plt

diamonds_data = sns.load_dataset("diamonds")

plt.figure(figsize=(10, 6))

sns.histplot(data=diamonds_data, x='price', hue='cut', multiple='stack')
plt.title('Histogram of Price by Cut')

plt.show()

# %%
# Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

import seaborn as sns
import matplotlib.pyplot as plt

iris_data = sns.load_dataset("iris")

sns.pairplot(data=iris_data, hue='species')

plt.show()

# %%
#Use the "flights" dataset from seaborn to plot a heatmap.

import seaborn as sns
import matplotlib.pyplot as plt


flights_data = sns.load_dataset("flights")

pivot_table = flights_data.pivot_table(index='month', columns='year', values='passengers')


plt.figure(figsize=(10, 6))


sns.heatmap(data=pivot_table, annot=True, fmt='d', cmap='YlGnBu')


plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Passenger Count Heatmap for Flights')

plt.show()
